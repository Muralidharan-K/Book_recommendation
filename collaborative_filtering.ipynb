# %%
#create dataframe from liked_books.csv
import pandas as pd
my_books = pd.read_csv("liked_books.csv", index_col=0)
my_books["book_id"] = my_books["book_id"].astype(str)

# %%
my_books # dataframe of my liked books
# Out:
#      user_id   book_id  rating  \
# 0         -1   2517439       5
# 1         -1    113576       5
# 2         -1     35100       5
# 3         -1    228221       5
# 5         -1  17662739       5
# 6         -1    356824       5
# 7         -1  12125412       5
# 8         -1    139069       5
# 10        -1     76680       5
# 11        -1      1898       5
# 12        -1   5096865       5
# 13        -1    228665       5
# 17        -1    437143       5
# 18        -1  18949861       5
# 19        -1   2913377       5
# 20        -1   1215032       5
# 21        -1    883438       5
# 22        -1   5578108       5
# 23        -1    128029       5
# 24        -1     77203       5
# 25        -1      5439       5
# 26        -1   1685995       5
# 27        -1   6448772       5
# 527       -1   8161140       1
# 528       -1     28187       1
# 531       -1  25659450       1
# 532       -1     82599       1
#
#                                                  title
# 0               The Forever War  (The Forever War, #1)
# 1    The Smartest Guys in the Room: The Amazing Ris...
# 2                                Battle Cry of Freedom
# 3                                  The Mask of Command
# 5           2001: A Space Odyssey  (Space Odyssey, #1)
# 6    India After Gandhi: The History of the World's...
# 7      The Lady or the Tiger?: and Other Logic Puzzles
# 8            Endurance: Shackleton's Incredible Voyage
# 10                        Foundation  (Foundation, #1)
# 11   Into Thin Air: A Personal Account of the Mount...
# 12                                       In Cold Blood
# 13       The Eye of the World  (The Wheel of Time, #1)
# 17                A Short History of Nearly Everything
# 18                                             Contact
# 19   The Name of the Wind  (The Kingkiller Chronicl...
# 20   The Wise Man's Fear  (The Kingkiller Chronicle...
# 21                                        East of Eden
# 22   From Colony to Superpower: U.S. Foreign Relati...
# 23                            A Thousand Splendid Suns
# 24                                     The Kite Runner
# 25                             Interpreter of Maladies
# 26                                     Dune  (Dune #1)
# 27   Quantum: Einstein, Bohr, and the Great Debate ...
# 527                                       On the Beach
# 528  The Lightning Thief  (Percy Jackson and the Ol...
# 531                                          Arkwright
# 532                                   Rabbits: A Novel

# %%
#convert book_id_map.csv file into dictionary
csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
book_set = set(my_books["book_id"])

# %%
book_set
# Out:
# {'113576',
#  '12125412',
#  '1215032',
#  '128029',
#  '139069',
#  '1685995',
#  '17662739',
#  '18949861',
#  '1898',
#  '228221',
#  '228665',
#  '2517439',
#  '25659450',
#  '28187',
#  '2913377',
#  '35100',
#  '356824',
#  '437143',
#  '5096865',
#  '5439',
#  '5578108',
#  '6448772',
#  '76680',
#  '77203',
#  '8161140',
#  '82599',
#  '883438'}

# %%
#creat user_id: count dictinory from goodreads_interactions.csv based on the same book_id that listed in book_set

overlap_users = {}
with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.strip().split(",")
        
        book_id = csv_book_mapping.get(csv_id)
        
        if book_id in book_set:
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 316341

# %%
my_books.shape[0]
# Out:
# 27

# %%
my_books.shape[1]
# Out:
# 4

# %%
#filter 20% of the overlap_users
filtered_overlap_users = set([key for key in overlap_users if overlap_users[key] > my_books.shape[0]/5])

# %%
len(filtered_overlap_users)
# Out:
# 1258

# %%
#create final list of user_id with its respective book_id and ratings
interactions_list = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in filtered_overlap_users:
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %%
len(interactions_list)
# Out:
# 5638701

# %%
interactions_list[0]
# Out:
# ['282', '627206', '4']

# %%
#create dataframe
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])

# %%
# concatenate my_books with interactions (user_books)
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1   2517439      5
# 1            -1    113576      5
# 2            -1     35100      5
# 3            -1    228221      5
# 5            -1  17662739      5
# ...         ...       ...    ...
# 5638696  804100    475178      0
# 5638697  804100    186074      0
# 5638698  804100    153008      0
# 5638699  804100     45107      0
# 5638700  804100   1762198      5
#
# [5638728 rows x 3 columns]

# %%
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
# create unique index for user_id
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
interactions
# Out:
#         user_id   book_id  rating  user_index
# 0            -1   2517439       5           0
# 1            -1    113576       5           0
# 2            -1     35100       5           0
# 3            -1    228221       5           0
# 5            -1  17662739       5           0
# ...         ...       ...     ...         ...
# 5638696  804100    475178       0        1183
# 5638697  804100    186074       0        1183
# 5638698  804100    153008       0        1183
# 5638699  804100     45107       0        1183
# 5638700  804100   1762198       5        1183
#
# [5638728 rows x 4 columns]

# %%
# create unique index for book_id
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
interactions
# Out:
#         user_id   book_id  rating  user_index  book_index
# 0            -1   2517439       5           0      414880
# 1            -1    113576       5           0       38971
# 2            -1     35100       5           0      575858
# 3            -1    228221       5           0      356004
# 5            -1  17662739       5           0      214285
# ...         ...       ...     ...         ...         ...
# 5638696  804100    475178       0        1183      617107
# 5638697  804100    186074       0        1183      258768
# 5638698  804100    153008       0        1183      141428
# 5638699  804100     45107       0        1183      611284
# 5638700  804100   1762198       5        1183      213203
#
# [5638728 rows x 5 columns]

# %%
# create sparse matrix
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
print(ratings_mat_coo)

# %%
ratings_mat_coo.shape
# Out:
# (1259, 802870)

# %%
#convert a sparse matrix (in COO format) into a compressed sparse row (CSR) format
ratings_mat = ratings_mat_coo.tocsr()

# %%
print(ratings_mat)

# %%
interactions[interactions["user_id"] == "-1"] # returns my liked book_id details

# %%
my_index = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index:], ratings_mat).flatten()

# %%
similarity
# Out:
# array([1.        , 0.04579826, 0.06143443, ..., 0.07970932, 0.0791374 ,
#        1.        ])

# %%
import numpy as np

indices = np.argpartition(similarity, -20)[-20:]

# %%
indices
# Out:
# array([1219680,  893340,  609840,  616140, 1367100, 1456560, 1108800,
#         567000,  323820,  221760, 1204560, 1009260,  840420, 1254960,
#         152460, 1205820,  987840,  254520,  989100, 1064700], dtype=int64)

# %%
similar_users = interactions[interactions["book_index"].isin(indices)].copy()

# %%
similar_users = similar_users[similar_users["user_id"]!="-1"]

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 24178      2001  18490591       0         314      254520
# 134734    13715  15789399       0         112      152460
# 422546    32978  34331816       0         696      567000
# 430879    33413  18490591       3         705      254520
# 442756    34085  17834830       0         724      221760
# 688417    58545  17834830       0        1102      221760
# 819826    66153  15789399       1        1123      152460
# 934921    77376  15789399       0        1168      152460
# 966020    78417  15789399       0        1171      152460
# 986327    78854  17834830       0        1175      221760
# 1066829   83250  15789399       0        1193      152460
# 1404192  108045  17834830       4          24      221760
# 1510478  117798  17834830       0          44      221760
# 1521379  118262  15789399       0          46      152460
# 1576246  119660  18490591       0          56      254520
# 1787828  134419    471031       0         105      616140
# 1864603  141311    471031       0         124      616140
# 2124240  165140  15789399       0         198      152460
# 2397268  180123  17834830       0         244      221760
# 2517781  192632   2156782       3         289      323820
# 2676216  198433  17834830       0         310      221760
# 2772503  206612  15789399       5         332      152460
# 2890737  219579  17834830       0         373      221760
# 3100666  241474  18490591       0         429      254520
# 3484484  279453  15789399       0         544      152460
# 3538823  280135  34331816       0         550      567000
# 3611028  286847    471031       0         573      616140
# 3633770  287955  15789399       0         582      152460
# 3903411  310443  15789399       0         647      152460
# 3926033  316762  15789399       0         656      152460
# 3938397  316845  18490591       0         657      254520
# 4045421  320562  15789399       0         667      152460
# 4077514  323698  15789399       0         677      152460
# 4160334  329899  18490591       0         697      254520
# 4223272  339532  18490591       0         720      254520
# 4356923  346652  17834830       0         743      221760
# 4415534  350801  17834830       0         752      221760
# 4442509  352790  15789399       0         761      152460
# 4495346  359399    445321       0         785      609840
# 4503503  359399  15789399       0         785      152460
# 4580890  365778    445321       0         797      609840
# 4618285  368287  15789399       0         802      152460
# 4726005  379734  15789399       0         827      152460
# 4743030  380533  15789399       0         832      152460
# 4822946  386880  15789399       0         851      152460
# 4976817  396456  15789399       0         884      152460
# 5110392  404801  15789399       0         913      152460
# 5326419  419922  17834830       0         967      221760
# 5345913  422386  15789399       0         976      152460
# 5348737  422438  15789399       0         977      152460

# %%
book_recs = similar_users.groupby("book_id")

# %%
print(book_recs.head(10))
# Out:
#         user_id   book_id  rating  user_index  book_index
# 24178      2001  18490591       0         314      254520
# 134734    13715  15789399       0         112      152460
# 422546    32978  34331816       0         696      567000
# 430879    33413  18490591       3         705      254520
# 442756    34085  17834830       0         724      221760
# 688417    58545  17834830       0        1102      221760
# 819826    66153  15789399       1        1123      152460
# 934921    77376  15789399       0        1168      152460
# 966020    78417  15789399       0        1171      152460
# 986327    78854  17834830       0        1175      221760
# 1066829   83250  15789399       0        1193      152460
# 1404192  108045  17834830       4          24      221760
# 1510478  117798  17834830       0          44      221760
# 1521379  118262  15789399       0          46      152460
# 1576246  119660  18490591       0          56      254520
# 1787828  134419    471031       0         105      616140
# 1864603  141311    471031       0         124      616140
# 2124240  165140  15789399       0         198      152460
# 2397268  180123  17834830       0         244      221760
# 2517781  192632   2156782       3         289      323820
# 2676216  198433  17834830       0         310      221760
# 2772503  206612  15789399       5         332      152460
# 2890737  219579  17834830       0         373      221760
# 3100666  241474  18490591       0         429      254520
# 3484484  279453  15789399       0         544      152460
# 3538823  280135  34331816       0         550      567000
# 3611028  286847    471031       0         573      616140
# 3633770  287955  15789399       0         582      152460
# 3938397  316845  18490591       0         657      254520
# 4160334  329899  18490591       0         697      254520
# 4223272  339532  18490591       0         720      254520
# 4356923  346652  17834830       0         743      221760
# 4415534  350801  17834830       0         752      221760
# 4495346  359399    445321       0         785      609840
# 4580890  365778    445321       0         797      609840

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#           count      mean
# book_id
# 15789399     24  0.250000
# 17834830     11  0.363636
# 18490591      7  0.428571
# 2156782       1  3.000000
# 34331816      2  0.000000
# 445321        2  0.000000
# 471031        3  0.000000

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#     book_id  count      mean  \
# 0  15789399     24  0.250000
# 1  17834830     11  0.363636
# 2  18490591      7  0.428571
# 3   2156782      1  3.000000
# 4  34331816      2  0.000000
# 5    445321      2  0.000000
# 6    471031      3  0.000000
#
#                                                title  ratings  \
# 0                                        Cross Roads     7125
# 1  Monsters: The 1985 Chicago Bears and the Wild ...      713
# 2  Labor Day: Birth Stories for the Twenty-first ...      213
# 3  Mallory and the Trouble With Twins (The Baby-S...       77
# 4                 The Slave Boy (The Orfeo Saga, #6)        6
# 5         Amy's Answering Machine: Messages from Mom      195
# 6                                     The Day We Met      104
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/15789399-c...
# 1  https://www.goodreads.com/book/show/17834830-m...
# 2  https://www.goodreads.com/book/show/18490591-l...
# 3  https://www.goodreads.com/book/show/2156782.Ma...
# 4  https://www.goodreads.com/book/show/34331816-t...
# 5  https://www.goodreads.com/book/show/445321.Amy...
# 6  https://www.goodreads.com/book/show/471031.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1347989200m...
# 1  https://images.gr-assets.com/books/1370797175m...
# 2  https://images.gr-assets.com/books/1393065823m...
# 3  https://s.gr-assets.com/assets/nophoto/book/11...
# 4  https://images.gr-assets.com/books/1487513205m...
# 5  https://s.gr-assets.com/assets/nophoto/book/11...
# 6  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                            mod_title
# 0                                        cross roads
# 1  monsters the 1985 chicago bears and the wild h...
# 2  labor day birth stories for the twentyfirst ce...
# 3  mallory and the trouble with twins the babysit...
# 4                     the slave boy the orfeo saga 6
# 5           amys answering machine messages from mom
# 6                                     the day we met

# %%
my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()
my_books["mod_title"] = my_books["mod_title"].str.replace("\s+", " ", regex=True)
#book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

# %%
book_recs
# Out:
#     book_id  count      mean  \
# 0  15789399     24  0.250000
# 1  17834830     11  0.363636
# 2  18490591      7  0.428571
# 3   2156782      1  3.000000
# 4  34331816      2  0.000000
# 5    445321      2  0.000000
# 6    471031      3  0.000000
#
#                                                title  ratings  \
# 0                                        Cross Roads     7125
# 1  Monsters: The 1985 Chicago Bears and the Wild ...      713
# 2  Labor Day: Birth Stories for the Twenty-first ...      213
# 3  Mallory and the Trouble With Twins (The Baby-S...       77
# 4                 The Slave Boy (The Orfeo Saga, #6)        6
# 5         Amy's Answering Machine: Messages from Mom      195
# 6                                     The Day We Met      104
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/15789399-c...
# 1  https://www.goodreads.com/book/show/17834830-m...
# 2  https://www.goodreads.com/book/show/18490591-l...
# 3  https://www.goodreads.com/book/show/2156782.Ma...
# 4  https://www.goodreads.com/book/show/34331816-t...
# 5  https://www.goodreads.com/book/show/445321.Amy...
# 6  https://www.goodreads.com/book/show/471031.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1347989200m...
# 1  https://images.gr-assets.com/books/1370797175m...
# 2  https://images.gr-assets.com/books/1393065823m...
# 3  https://s.gr-assets.com/assets/nophoto/book/11...
# 4  https://images.gr-assets.com/books/1487513205m...
# 5  https://s.gr-assets.com/assets/nophoto/book/11...
# 6  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                            mod_title
# 0                                        cross roads
# 1  monsters the 1985 chicago bears and the wild h...
# 2  labor day birth stories for the twentyfirst ce...
# 3  mallory and the trouble with twins the babysit...
# 4                     the slave boy the orfeo saga 6
# 5           amys answering machine messages from mom
# 6                                     the day we met

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Go to website</a>'.format(val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

book_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_75a69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75a69_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_75a69_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_75a69_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_75a69_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_75a69_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_75a69_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_75a69_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_75a69_level0_col7" class="col_heading level0 col7" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75a69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75a69_row0_col0" class="data row0 col0" >15789399</td>
#       <td id="T_75a69_row0_col1" class="data row0 col1" >24</td>
#       <td id="T_75a69_row0_col2" class="data row0 col2" >0.250000</td>
#       <td id="T_75a69_row0_col3" class="data row0 col3" >Cross Roads</td>
#       <td id="T_75a69_row0_col4" class="data row0 col4" >7125</td>
#       <td id="T_75a69_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/15789399-cross-roads">Go to website</a></td>
#       <td id="T_75a69_row0_col6" class="data row0 col6" ><a href="https://images.gr-assets.com/books/1347989200m/15789399.jpg"><img src="https://images.gr-assets.com/books/1347989200m/15789399.jpg" width=50></img></a></td>
#       <td id="T_75a69_row0_col7" class="data row0 col7" >cross roads</td>
#     </tr>
#     <tr>
#       <th id="T_75a69_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75a69_row1_col0" class="data row1 col0" >17834830</td>
#       <td id="T_75a69_row1_col1" class="data row1 col1" >11</td>
#       <td id="T_75a69_row1_col2" class="data row1 col2" >0.363636</td>
#       <td id="T_75a69_row1_col3" class="data row1 col3" >Monsters: The 1985 Chicago Bears and the Wild Heart of Football</td>
#       <td id="T_75a69_row1_col4" class="data row1 col4" >713</td>
#       <td id="T_75a69_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/17834830-monsters">Go to website</a></td>
#       <td id="T_75a69_row1_col6" class="data row1 col6" ><a href="https://images.gr-assets.com/books/1370797175m/17834830.jpg"><img src="https://images.gr-assets.com/books/1370797175m/17834830.jpg" width=50></img></a></td>
#       <td id="T_75a69_row1_col7" class="data row1 col7" >monsters the 1985 chicago bears and the wild heart of football</td>
#     </tr>
#     <tr>
#       <th id="T_75a69_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75a69_row2_col0" class="data row2 col0" >18490591</td>
#       <td id="T_75a69_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_75a69_row2_col2" class="data row2 col2" >0.428571</td>
#       <td id="T_75a69_row2_col3" class="data row2 col3" >Labor Day: Birth Stories for the Twenty-first Century: Thirty Artful, Unvarnished, Hilarious, Harrowing, Totally True Tales</td>
#       <td id="T_75a69_row2_col4" class="data row2 col4" >213</td>
#       <td id="T_75a69_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/18490591-labor-day">Go to website</a></td>
#       <td id="T_75a69_row2_col6" class="data row2 col6" ><a href="https://images.gr-assets.com/books/1393065823m/18490591.jpg"><img src="https://images.gr-assets.com/books/1393065823m/18490591.jpg" width=50></img></a></td>
#       <td id="T_75a69_row2_col7" class="data row2 col7" >labor day birth stories for the twentyfirst century thirty artful unvarnished hilarious harrowing totally true tales</td>
#     </tr>
#     <tr>
#       <th id="T_75a69_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75a69_row3_col0" class="data row3 col0" >2156782</td>
#       <td id="T_75a69_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_75a69_row3_col2" class="data row3 col2" >3.000000</td>
#       <td id="T_75a69_row3_col3" class="data row3 col3" >Mallory and the Trouble With Twins (The Baby-Sitters Club, #21)</td>
#       <td id="T_75a69_row3_col4" class="data row3 col4" >77</td>
#       <td id="T_75a69_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2156782.Mallory_and_the_Trouble_With_Twins">Go to website</a></td>
#       <td id="T_75a69_row3_col6" class="data row3 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_75a69_row3_col7" class="data row3 col7" >mallory and the trouble with twins the babysitters club 21</td>
#     </tr>
#     <tr>
#       <th id="T_75a69_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_75a69_row4_col0" class="data row4 col0" >34331816</td>
#       <td id="T_75a69_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_75a69_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_75a69_row4_col3" class="data row4 col3" >The Slave Boy (The Orfeo Saga, #6)</td>
#       <td id="T_75a69_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_75a69_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/34331816-the-slave-boy">Go to website</a></td>
#       <td id="T_75a69_row4_col6" class="data row4 col6" ><a href="https://images.gr-assets.com/books/1487513205m/34331816.jpg"><img src="https://images.gr-assets.com/books/1487513205m/34331816.jpg" width=50></img></a></td>
#       <td id="T_75a69_row4_col7" class="data row4 col7" >the slave boy the orfeo saga 6</td>
#     </tr>
#     <tr>
#       <th id="T_75a69_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_75a69_row5_col0" class="data row5 col0" >445321</td>
#       <td id="T_75a69_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_75a69_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_75a69_row5_col3" class="data row5 col3" >Amy's Answering Machine: Messages from Mom</td>
#       <td id="T_75a69_row5_col4" class="data row5 col4" >195</td>
#       <td id="T_75a69_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/445321.Amy_s_Answering_Machine">Go to website</a></td>
#       <td id="T_75a69_row5_col6" class="data row5 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_75a69_row5_col7" class="data row5 col7" >amys answering machine messages from mom</td>
#     </tr>
#     <tr>
#       <th id="T_75a69_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_75a69_row6_col0" class="data row6 col0" >471031</td>
#       <td id="T_75a69_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_75a69_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_75a69_row6_col3" class="data row6 col3" >The Day We Met</td>
#       <td id="T_75a69_row6_col4" class="data row6 col4" >104</td>
#       <td id="T_75a69_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/471031.The_Day_We_Met">Go to website</a></td>
#       <td id="T_75a69_row6_col6" class="data row6 col6" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_75a69_row6_col7" class="data row6 col7" >the day we met</td>
#     </tr>
#   </tbody>
# </table>
